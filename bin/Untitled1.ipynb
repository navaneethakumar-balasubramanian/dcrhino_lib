# %%
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
ts = np.load('/home/thiago/detour_lake_mine/output/1/ts.npy')
ts_date = map(datetime.fromtimestamp,ts)

plt.plot(ts_date,np.load('/home/thiago/detour_lake_mine/output/1/axial.npy'))

plt.show()

# %%
ts = np.load('/home/thiago/detour_lake_mine/holes/88,5,221,DR5,S1020/ts.npy')
ts_date = map(datetime.utcfromtimestamp,ts)
# Out:
# 1542645893

# %%
plt.plot(ts_date,np.load('/home/thiago/detour_lake_mine/holes/88,5,221,DR5,S1020/axial.npy'))
plt.show()

# %%
total = np.load('/home/thiago/detour_lake_mine/output/1/axial.npy')

# %%
ts_min = 1542645893
ts_max = 1542647764
ts_min - ts[0]
f  = ts_min - ts[0]
t = f + ts_max-ts_min
print f,t,total.shape

        

plt.plot(total[10000:20000])
plt.show()
# Out:
# 3041 4912 (20537, 560)

# %%
pos_array
# Out:
# array([[   0,    1,    2, ..., 1868, 1869, 1870]])

# %%
ts_date = map(datetime.utcfromtimestamp,ts)
ts_date[0]
# Out:
# datetime.datetime(2018, 11, 19, 15, 54, 12)
